# %% [markdown]
# ## ColExpand

# %%
import pandas as pd

# %%
columns = [
    'SRP', 'ACCESSION', 'RUN_SET.RUN.IDENTIFIERS.PRIMARY_ID', 
    'SAMPLE.SAMPLE_NAME.TAXON_ID', 'Pool.Member.@sample_title', 'TAG', 'VALUE']
dF = pd.read_table('SRP_dump/TE_SRP_expanded.csv',delimiter=',') 
dF = pd.DataFrame(dF, columns=columns)

# %%
tags = list(set(dF['TAG']))

# %%
groups = dF.groupby(['ACCESSION']).groups
expanded = []
for acc in groups:
    gr = dF.iloc[[*groups[acc]]]
    obj = dict(zip(gr['TAG'], gr['VALUE']))
    for col in columns[0:-2]:
        obj[col] = list(gr[col])[0]
    expanded.append({k:obj[k] for k in obj if obj[k] != ""})

# %%
pd.DataFrame(expanded, columns=columns[0:-2] + tags).to_csv("SRP_dump/TE_SRP_tagvalue.tsv", index=False, sep="\t")

# %%
def counts(obj):
    cntx = {}
    for c in list(obj):
        if c not in cntx: cntx[c] = 0
        cntx[c] += 1
    return sorted(cntx.items(), key=lambda item: item[1], reverse=True)

filtred = []
stats = {}
total = max(dF.count())
for tag in tags:
    cntx = counts(dF[dF.TAG == tag]['VALUE'])
    empty = 100 * ( 1 - sum([v for k,v in cntx])/total )
    stats[tag] = empty
    if empty < 99.5:
        filtred.append(tag)
    print(f"# {tag} (EMPTY: {empty:.2f}%)")
    for k, v in cntx:
        print(f"   ({v})  {k}")

[(k,v) for k,v in sorted(stats.items(), key=lambda item: item[1])]
# Out:
# # replicate (EMPTY: 96.10%)
#    (19)  Replicate 2
#    (19)  Replicate 1
#    (16)  Replicate 3
#    (10)  Replicate #2
#    (10)  Replicate #1
#    (6)  3
#    (6)  2
#    (6)  1
# # infection (EMPTY: 99.83%)
#    (1)  PRMT5 shRNA
#    (1)  WDR77 shRNA
#    (1)  Scrambled control shRNA_2
#    (1)  Scrambled control shRNA_1
# # sequencing_library_method (EMPTY: 99.96%)
#    (1)  Illumina Nextera XT
# # lab_host (EMPTY: 99.96%)
#    (1)  Bos taurus
# # passage_history (EMPTY: 99.96%)
#    (1)  Passaged once in LFBK-_V_6 cells
# # serotype (EMPTY: 99.96%)
#    (1)  A
# # case history of originator (EMPTY: 99.75%)
#    (6)  HBs-Ag positive hepato cellular carcinoma (Ed.III) with liver cirrhosis. HBs-Ag(+), HBs-Ab(-), HBe-Ag(-), HBe-Ab(+), HBc-Ab(+), AFP positive (110,000 ng/ml).
# # genotype/variation (EMPTY: 98.09%)
#    (12)  expressing sgRNA targeting PRMT5
#    (7)  PRMT5 knockdown
#    (6)  No knockdown
#    (3)  shPRMT5
#    (3)  shCTRL
#    (2)  Expressing Dox inducible GFP-SMN fusion protein. Construct is hygromycin resistant.
#    (2)  Expressing shRNA targeting SMN under CMV promoter.
#    (2)  Expressing shRNA targeting GFP under CMV promoter.
#    (1)  Wild type
#    (1)  Expressing amanitin-resistant R1810A mutant POLR2A
#    (1)  Expressing amanitin-resistant wt POLR2A
#    (1)  control
#    (1)  siNC-2
#    (1)  siNC-1
#    (1)  siPRMT5-2
#    (1)  siPRMT5-1
# # timepoint_days_post_infection (EMPTY: 99.96%)
#    (1)  3
# # stress (EMPTY: 99.49%)
#    (6)  2 Gy radiation
#    (6)  0 Gy radiation
# # polysome fraction (EMPTY: 99.49%)
#    (3)  bound with three or more ribosomes
#    (3)  bound with two ribosomes
#    (3)  bound with one ribosome (monosome)
#    (3)  total input
# # biological replicates (EMPTY: 99.32%)
#    (6)  BR3
#    (6)  BR2
#    (4)  BR1
# # barcode (EMPTY: 97.97%)
#    (4)  SI-TT-F6
#    (4)  SI-TT-E5
#    (4)  SI-TT-D4
#    (4)  SI-TT-C3
#    (4)  SI-TT-B2
#    (4)  SI-TT-A1
#    (4)  SI-TT-G6
#    (4)  SI-TT-F5
#    (4)  SI-TT-E4
#    (4)  SI-TT-D3
#    (4)  SI-TT-C2
#    (4)  SI-TT-B1
# # isolation_source (EMPTY: 99.96%)
#    (1)  laboratory / experimental
# # knockdown (EMPTY: 98.94%)
#    (6)  shpICln
#    (6)  shMEP50
#    (4)  shPRMT5
#    (3)  MEP50 knockdown
#    (3)  PRMT5 knockdown
#    (3)  GFP (control knockdown)
# # age (EMPTY: 99.75%)
#    (6)  48Y
# # note (EMPTY: 99.96%)
#    (1)  Experimental inocculum was A24/Cruzeiro/BoPass2 Harvested 28Dec2005, SRA accession: SRP149386
# # donor id (EMPTY: 99.83%)
#    (2)  CB12
#    (2)  CB11
# # cell line background (EMPTY: 99.75%)
#    (6)  MCF7
# # reference genome (EMPTY: 99.49%)
#    (12)  human genome hg38
# # source_name (EMPTY: 77.18%)
#    (32)  PBMC
#    (24)  HEK293T cell line
#    (22)  Z-138 cells
#    (20)  cell line VCaP
#    (20)  Pancreatic cancer cell line
#    (20)  Osteosarcoma
#    (18)  Cancer cell line
#    (16)  Molm13
#    (16)  Human castration-resistant prostate cancer cells 22Rv1
#    (16)  Lymph Node
#    (12)  Prostate cancer
#    (12)  SUDHL6 cells
#    (12)  CHL1 cell line
#    (12)  CHL1AR991 cell line
#    (12)  A375 cell line
#    (12)  A375AR991 cell line
#    (12)  breast cancer cells
#    (9)  A549
#    (8)  CD34+ HSPCs from cord blood
#    (8)  T cells
#    (8)  Endometrium
#    (8)  CHL1
#    (7)  Raji (lymphocyte)
#    (6)  HEK293
#    (6)  HCT116 stable cells with E2F1 knockdown
#    (6)  HCT116 stable cells
#    (6)  Melanoma, Verafinib
#    (6)  Melanoma, untreated
#    (6)  Human lung adenocarcinoma cell line
#    (5)  U2OS cells
#    (4)  Hela cells (cervical cancer cells)
#    (4)  CellLine: SU-DHL-4
#    (4)  CellLine: SU-DHL-5
#    (4)  CellLine: SU-DHL-6
#    (4)  CellLine: JVM-2
#    (4)  CellLine: MAVER-1
#    (4)  Acute myeloid leukemia cell line
#    (4)  HeLa cell
#    (4)  doxorubicin-resistant MCF7 (MCF7-DR)
#    (4)  parental MCF7
#    (3)  AML cell line (MV4-11)_scrambled
#    (3)  AML cell line (MV4-11)_PMRT5/Knockdown
#    (3)  A549 lung adenocarcinoma MEP50 shRNA knockdown
#    (3)  A549 lung adenocarcinoma PRMT5 shRNA knockdown
#    (3)  A549 lung adenocarcinoma control (GFP) knockdown
#    (3)  U-87 MG cells, EPZ015666
#    (3)  U-87 MG cells, DMSO
#    (3)  MCF7 shPRMT5 ESA+CD24lowCD44+ cells
#    (3)  MCF7 shCTRL ESA+CD24lowCD44+ cells
#    (3)  KK U2OS stable cells
#    (3)  R109K U2OS stable cells
#    (3)  WT U2OS stable cells
#    (3)  pTRE U2OS stable cells
#    (3)  96h PF-9927 activated CD3+
#    (3)  96h DMSO activated CD3+
#    (3)  72h PF-9927 activated CD8+
#    (3)  72h DMSO activated CD8+
#    (3)  Naïve CD8+
#    (3)  72h PF-9927 activated CD4+
#    (3)  shPRMT5, JHH-7 cells
#    (3)  Vector, JHH-7 cells
#    (3)  HCT116 CCL-247_WT PRMT5
#    (3)  HCT116 CCL-247_ADA PRMT5
#    (3)  bladder cancer cell line UM-UC-3
#    (3)  bladder cancer cell line T24
#    (2)  MDA-MB-231
#    (2)  OCI-Ly7 sgPRMT5 6 days
#    (2)  OCI-Ly7 sgPRMT5 3 days
#    (2)  OCI-Ly7 sgPRMT5 0 day
#    (2)  TMD8 sgPRMT5 6 days
#    (2)  TMD8 sgPRMT5 3 days
#    (2)  TMD8 sgPRMT5 0 day
#    (2)  A375-CTX-72hr
#    (2)  A375-PD991-72hr
#    (2)  A375-DMSO-72hr
#    (2)  72h DMSO activated CD4+
#    (2)  Tu686_siNC
#    (2)  Tu686_siPRMT5
#    (2)  Tu212 cells
#    (1)  HEK293 cell line transfected with Flag-ZNF224, Flag ChIP
#    (1)  PRMT5 shRNA
#    (1)  WDR77 shRNA
#    (1)  Scrambled control shRNA (control for PRMT5 shRNA)
#    (1)  Scrambled control shRNA (control for WDR77 shRNA)
#    (1)  PRMT5
#    (1)  Input
#    (1)  NGP cells treated with JSK591 replicate 2
#    (1)  NGP cells treated with JSK591 replicate 1
#    (1)  NGP cells treated with DMSO replicate 2
#    (1)  NGP cells treated with DMSO replicate 1
#    (1)  CHLA-20 cells treated with JSK591 replicate 2
#    (1)  CHLA-20 cells treated with JSK591 replicate 1
#    (1)  CHLA-20 cells treated with DMSO replicate 2
#    (1)  CHLA-20 cells treated with DMSO replicate 1
#    (1)  SA-SPLICE19-4_S4
#    (1)  SA-SPLICE19-3_S3
#    (1)  SA-SPLICE19-2_S2
#    (1)  SA-SPLICE19-1_S1
# # disease (EMPTY: 97.97%)
#    (32)  Richter's Transformation
#    (16)  Chronic Lymphocytic Leukemia
# # treatment (EMPTY: 86.71%)
#    (24)  No treatment
#    (21)  DMSO
#    (16)  DHT
#    (12)  increasing concentrations of palbociclib for 3 months
#    (12)  increasing concentrations of palbociclib for 7 months
#    (10)  untreated
#    (9)  PRMT5i
#    (6)  Dox+
#    (6)  Dox-
#    (6)  200nm GSK591
#    (6)  Vehicle (0.01% DMSO)
#    (6)  Treated (GSK3368712)
#    (6)  Control (DMSO)
#    (6)  72h PF-9927
#    (6)  2 µM Verafinib for 20 days
#    (6)  Treated with 5µM GSK591 and 5µM Ro for 24hr
#    (6)  Treated with 5µM Ro for 24hr
#    (6)  CDK4/6 inhibition
#    (5)  72h DMSO
#    (5)  Treated with 5µM GSK591 for 24hr
#    (5)  Treated with DMSO for 24hr
#    (4)  Infected cells were selected with puromycin (1mg/mL) for 5 days
#    (4)  R1881
#    (4)  Treated (Combination)
#    (4)  Treated (GSK3203591)
#    (4)  treated with PRMT4 inhibitor
#    (4)  treated with PRMT1 inhibitor
#    (4)  treated with DMSO
#    (4)  parental cells treated with DOX
#    (4)  parental cells
#    (4)  treated with 1 μM doxorubicin hydrochloride
#    (4)  JSK591
#    (4)  Control
#    (3)  EPZ015666
#    (3)  96h PF-9927
#    (3)  96h DMSO
#    (3)  MS023
#    (3)  GSK591
#    (3)  PRMT5 shRNA transfection
#    (3)  Empty vector transfection
#    (3)  WT
#    (3)  ADA treatment
#    (3)  lentivirus infection NCI-H460 for shRNA against PRMT5
#    (3)  lentivirus infection NCI-H460 for shRNA against GFP
#    (2)  no treatment
#    (2)  GSK3326595 (CTX) - 72hr
#    (2)  Palbociclib (PD991) - 72hr
#    (2)  Vehicle (DMSO) - 72 hr
#    (2)  15 µM PF-366
#    (2)  PRMT7 knockdown
#    (2)  PRMT5 knockdown
#    (2)  PRMT4 knockdown
#    (2)  PRMT3 knockdown
#    (2)  PRMT1 knockdown
#    (2)  parental cells overexpressed with PRMT6 under DOX treatment
#    (2)  parental cells overexpressed with PRMT5 under DOX treatment
#    (2)  0.04 OD Si-RNA-2
#    (2)  0.04 OD Si-RNA-1
#    (2)  Negative control
#    (2)  PRMT5 inhibition
#    (1)  5µM HPTB for 4 hours at 37°C
#    (1)  5µM DMSO for 4 hours at 37°C
#    (1)  RPHD19 T cells CD3/CD28 +PRMT5 INHIBITOR
#    (1)  RPHD19 T cells CD3/CD28 +DMSO
#    (1)  RPHD18 T cells CD3/CD28 +PRMT5 INHIBITOR
#    (1)  RPHD18 T cells CD3/CD28 +DMSO
#    (1)  RPHD17 T cells CD3/CD28 +PRMT5 INHIBITOR
#    (1)  RPHD17 T cells CD3/CD28 +DMSO
#    (1)  RPHD7 T cells CD3/CD28 +PRMT5 INHIBITOR
#    (1)  RPHD7 T cells CD3/CD28 +DMSO
#    (1)  siPRMT7-HEK293
#    (1)  siPRMT5-HEK293
#    (1)  siPRMT4-HEK293
#    (1)  siCTL-HEK293
#    (1)  PRMT6 knockdown
#    (1)  Scramble shRNA control
# # tissue (EMPTY: 95.77%)
#    (32)  PBMC
#    (24)  peripheral blood
#    (16)  Lymph Node
#    (12)  breast cancer cells
#    (8)  Endometrium
#    (4)  Human Embryonic Kidney
#    (1)  SA-SPLICE19-4_S4
#    (1)  SA-SPLICE19-3_S3
#    (1)  SA-SPLICE19-2_S2
#    (1)  SA-SPLICE19-1_S1
# # genotype (EMPTY: 97.21%)
#    (12)  BRAFV600E
#    (12)  WT
#    (8)  control
#    (7)  PRMT5 knockdown
#    (6)  MTAP-/-
#    (5)  XRN2 KD
#    (5)  PRMT5 KD
#    (4)  DDX5 KD
#    (3)  Control
#    (1)  XRN2 KD input
#    (1)  PRMT5 KD input
#    (1)  DDX5 KD input
#    (1)  PRMT5 overexpression
# # genetics (EMPTY: 99.83%)
#    (4)  t(4;11)(q21;q23)
# # overexpression (EMPTY: 99.07%)
#    (12)  Overexpressing empty vector
#    (10)  Overexpressing MSI2-HyperADAR fusion
# # tumor type (EMPTY: 99.15%)
#    (12)  Diffuse Large B-cell Lymphoma
#    (8)  Mantle Cell Lymphoma
# # isolate (EMPTY: 99.96%)
#    (1)  non-vaccinated bovine 14-34
# # geo_loc_name (EMPTY: 99.96%)
#    (1)  not applicable
# # chip antibody (EMPTY: 98.52%)
#    (12)  AR
#    (8)  ERG
#    (5)  Monoclonal S9.6
#    (4)  none
#    (1)  anti-Flag M2
#    (1)  PRMT5 (Bethyl Labs A300-849A)
#    (1)  none (input)
#    (1)  PRMT5
#    (1)  MTA1
#    (1)  Snail
# # time (EMPTY: 99.32%)
#    (8)  24h
#    (4)  48h
#    (4)  0h
# # ectopic e2f-1 expressed (EMPTY: 99.49%)
#    (3)  HA-tagged R111/113K mutated E2F-1 (KK)
#    (3)  HA-tagged R109K mutated E2F-1
#    (3)  HA-tagged wild-type E2F-1
#    (3)  empty vector cell line
# # treatment2 (EMPTY: 99.66%)
#    (8)  8-Br-cAMP,MPA
# # genetic aberration (EMPTY: 99.83%)
#    (2)  control
#    (2)  t(4;11)(q21;q23)
# # shRNA (EMPTY: 99.15%)
#    (6)  PRMT5 sh2
#    (5)  PRMT5 sh1
#    (5)  PRMT5 NTC
#    (4)  PRMT5 sh3
# # treated with (EMPTY: 98.65%)
#    (10)  200nM GSK3326595
#    (10)  Vehicle
#    (4)  20ng/ml doxycycline for 6 days.
#    (4)  20ng/ml doxycycline for 3 days.
#    (4)  20ng/ml doxycycline for 0 days.
# # concentration (EMPTY: 99.75%)
#    (3)  10 uM
#    (3)  10 ul per 10 ml media
# # sample_type (EMPTY: 99.96%)
#    (1)  Saliva
# # agent (EMPTY: 99.32%)
#    (8)  Dox +
#    (8)  Dox -
# # time point (EMPTY: 97.88%)
#    (12)  48hr after retrovirus transduction
#    (10)  Day 6
#    (10)  Day 3
#    (10)  48hr after transduction
#    (6)  72 hours
#    (2)  6 days
# # cell line (EMPTY: 82.39%)
#    (37)  U2OS
#    (24)  HEK293T
#    (22)  A375
#    (22)  Z-138 cells
#    (20)  VCaP
#    (20)  CHL1
#    (18)  HCT116
#    (16)  PANC03.27
#    (16)  Molm13
#    (12)  LNCaP-shPRMT5
#    (12)  SUDHL6
#    (12)  CHL1AR991
#    (12)  A375AR991
#    (12)  MDA-MB-231
#    (9)  A549 lung adenocarcinoma
#    (9)  A549
#    (8)  breast cancer cell line MDA-MB-231
#    (6)  MV4-11
#    (6)  U-87 MG
#    (6)  OCI-Ly7
#    (6)  TMD8
#    (6)  M14s
#    (6)  A375s
#    (6)  HCC cell line JHH-7
#    (6)  H441
#    (6)  A427
#    (6)  H1975
#    (6)  NCI-H460
#    (5)  HEK293
#    (4)  Hela
#    (4)  SU-DHL-4
#    (4)  SU-DHL-5
#    (4)  SU-DHL-6
#    (4)  JVM-2
#    (4)  MAVER-1
#    (4)  PANC08.13
#    (4)  THP-1
#    (4)  HeLa
#    (4)  Tu686
#    (4)  MCF7-DR
#    (4)  MCF7
#    (4)  NGP
#    (4)  CHLA-20
#    (3)  bladder cancer cell line UM-UC-3
#    (3)  bladder cancer cell line T24
#    (2)  Tu212
# # tissue source (EMPTY: 97.46%)
#    (54)  Melanoma
#    (6)  Colorectal
# # treatment1 (EMPTY: 99.66%)
#    (4)  GSK591
#    (4)  solvent
# # BioSampleModel (EMPTY: 99.96%)
#    (1)  Viral
# # antibody (EMPTY: 99.53%)
#    (2)  RNAPII (N20) (Santa Cruz pAb Cat # sc-899)
#    (2)  RNAPII CTD, phospho-S5 (4h8) (Abcam mAb Cat # ab5408)
#    (2)  RNAPII CTD (8wg16) (purified in the lab)
#    (2)  SRSF1 antibody
#    (1)  IgG (Invitrogen Cat # 10500C)
#    (1)  GFP (Abcam pAb Cat# 290)
#    (1)  SMN (Santa Cruz pAb Cat # H-195)
# # collection_date (EMPTY: 99.96%)
#    (1)  not applicable
# # mtap status (EMPTY: 99.15%)
#    (8)  Knock out
#    (8)  Parental
#    (4)  nan
# # incubation time (EMPTY: 99.75%)
#    (6)  72h
# # vector (EMPTY: 99.49%)
#    (3)  E2F1 knockdown cell line treated with PRMT5 inhibitor
#    (3)  E2F1 knockdown cell line
#    (3)  empty vector cell line treated with PRMT5 inhibitor
#    (3)  empty vector cell line
# # conditions (EMPTY: 99.03%)
#    (12)  1ug/ml doxycycline, 24h
#    (6)  PRMT5 inhibitor treatment: 1uM, 48h
#    (2)  25nM p100/TSN siRNA, 72h
#    (2)  25nM NT siRNA, 72h
#    (1)  25nM E2F-1 siRNA, 72h
# # transfection (EMPTY: 99.79%)
#    (2)  esiRNA targeting PRMT9 (1ug esiRNA/10cm dish)
#    (2)  control esiRNA
#    (1)  Flag-ZNF224
# # condition (EMPTY: 99.32%)
#    (4)  PRMT5 and EZH2 Inhibition
#    (4)  PRMT5 Inhibition
#    (4)  EZH2 Inhibition
#    (4)  DMSO Control
# # cell type (EMPTY: 93.35%)
#    (22)  Mantle cell lymphoma cell line
#    (20)  Naive T lymphocytes
#    (17)  Osteosarcoma, epithelial
#    (16)  Acute Myeloid Leukemia
#    (12)  Colorectal carcinoma
#    (12)  melanoma cell
#    (9)  epithelial
#    (8)  stromal cells
#    (7)  Raji (EBNA 1 positive)
#    (6)  ESA+CD24lowCD44+ cells
#    (6)  GCB DLBCL cell line
#    (6)  ABC DLBCL cell line
#    (6)  Epithelial-derived cells
#    (4)  CD34+ HSPCs from cord blood
#    (4)  monocyte
#    (2)  HEK293
# # culture type (EMPTY: 99.83%)
#    (4)  suspension
# # time of treatment (EMPTY: 99.49%)
#    (6)  96 h
#    (6)  24 h
# [('source_name', 77.18035563082134),
#  ('cell line', 82.38780694326842),
#  ('treatment', 86.70618120237087),
#  ('cell type', 93.35309060118544),
#  ('tissue', 95.76629974597799),
#  ('replicate', 96.10499576629975),
#  ('genotype', 97.20575783234547),
#  ('tissue source', 97.45977984758679),
#  ('time point', 97.883149872989),
#  ('barcode', 97.96782387806944),
#  ('disease', 97.96782387806944),
#  ('genotype/variation', 98.09483488569009),
#  ('chip antibody', 98.5182049110923),
#  ('treated with', 98.64521591871296),
#  ('knockdown', 98.94157493649449),
#  ('conditions', 99.02624894157493),
#  ('overexpression', 99.06858594411516),
#  ('tumor type', 99.15325994919559),
#  ('shRNA', 99.15325994919559),
#  ('mtap status', 99.15325994919559),
#  ('biological replicates', 99.32260795935647),
#  ('time', 99.32260795935647),
#  ('agent', 99.32260795935647),
#  ('condition', 99.32260795935647),
#  ('stress', 99.49195596951735),
#  ('polysome fraction', 99.49195596951735),
#  ('reference genome', 99.49195596951735),
#  ('ectopic e2f-1 expressed', 99.49195596951735),
#  ('vector', 99.49195596951735),
#  ('time of treatment', 99.49195596951735),
#  ('antibody', 99.53429297205759),
#  ('treatment2', 99.66130397967824),
#  ('treatment1', 99.66130397967824),
#  ('case history of originator', 99.74597798475868),
#  ('age', 99.74597798475868),
#  ('cell line background', 99.74597798475868),
#  ('concentration', 99.74597798475868),
#  ('incubation time', 99.74597798475868),
#  ('transfection', 99.7883149872989),
#  ('infection', 99.83065198983911),
#  ('donor id', 99.83065198983911),
#  ('genetics', 99.83065198983911),
#  ('genetic aberration', 99.83065198983911),
#  ('culture type', 99.83065198983911),
#  ('sequencing_library_method', 99.95766299745978),
#  ('lab_host', 99.95766299745978),
#  ('passage_history', 99.95766299745978),
#  ('serotype', 99.95766299745978),
#  ('timepoint_days_post_infection', 99.95766299745978),
#  ('isolation_source', 99.95766299745978),
#  ('note', 99.95766299745978),
#  ('isolate', 99.95766299745978),
#  ('geo_loc_name', 99.95766299745978),
#  ('sample_type', 99.95766299745978),
#  ('BioSampleModel', 99.95766299745978),
#  ('collection_date', 99.95766299745978)]

# %%
pd.DataFrame(expanded, columns=columns[0:-2] + filtred).to_csv("SRP_dump/TE_SRP_tagvalue_filterd.tsv", index=False, sep="\t")
